# %% [markdown]
# <a href="https://colab.research.google.com/github/AdrianGabryla/MachineLearning/blob/main/02_mathematical_building_blocks.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# This is a companion notebook for the book [Deep Learning with Python, Second Edition](https://www.manning.com/books/deep-learning-with-python-second-edition?a_aid=keras&a_bid=76564dff). For readability, it only contains runnable code blocks and section titles, and omits everything else in the book: text paragraphs, figures, and pseudocode.
#
# **If you want to be able to follow what's going on, I recommend reading the notebook side by side with your copy of the book.**
#
# This notebook was generated for TensorFlow 2.6.

# %% [markdown]
# # The mathematical building blocks of neural networks

# %% [markdown]
# ## A first look at a neural network

# %% [markdown]
# **Loading the MNIST dataset in Keras**

# %%
from tensorflow.keras.datasets import mnist
(train_images, train_labels), (test_images, test_labels) = mnist.load_data()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11490434/11490434 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step

# %%
train_images.shape
# Out:
# (60000, 28, 28)

# %%
len(train_labels)
# Out:
# 60000

# %%
train_labels
# Out:
# array([5, 0, 4, ..., 5, 6, 8], dtype=uint8)

# %%
test_images.shape
# Out:
# (10000, 28, 28)

# %%
len(test_labels)
# Out:
# 10000

# %%
test_labels
# Out:
# array([7, 2, 1, ..., 4, 5, 6], dtype=uint8)

# %% [markdown]
# **The network architecture**

# %%
from tensorflow import keras
from tensorflow.keras import layers
model = keras.Sequential([
    layers.Dense(512, activation="relu"),
    layers.Dense(10, activation="softmax")
])

# %% [markdown]
# **The compilation step**

# %%
model.compile(optimizer="rmsprop",
              loss="sparse_categorical_crossentropy",
              metrics=["accuracy"])

# %% [markdown]
# **Preparing the image data**

# %%
train_images = train_images.reshape((60000, 28 * 28))
train_images = train_images.astype("float32") / 255
test_images = test_images.reshape((10000, 28 * 28))
test_images = test_images.astype("float32") / 255

# %% [markdown]
# **"Fitting" the model**

# %%
import matplotlib.pyplot as plt

history = model.fit(
    train_images, train_labels,
    epochs=10,
    batch_size=128,
    validation_split=0.2
)

def plot_history(history):
    acc = history.history['accuracy']
    val_acc = history.history['val_accuracy']
    loss = history.history['loss']
    val_loss = history.history['val_loss']
    epochs = range(1, len(acc) + 1)

    plt.figure(figsize=(12, 5))

    plt.subplot(1, 2, 1)
    plt.plot(epochs, loss, 'bo', label='Strata trenowania')
    plt.plot(epochs, val_loss, 'b', label='Strata walidacji')
    plt.title('Strata trenowania i walidacji')
    plt.legend()

    plt.subplot(1, 2, 2)
    plt.plot(epochs, acc, 'ro', label='Dokładność trenowania')
    plt.plot(epochs, val_acc, 'r', label='Dokładność walidacji')
    plt.title('Dokładność trenowania i walidacji')
    plt.legend()

    plt.show()

plot_history(history)
# Out:
# Epoch 1/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 7s 14ms/step - accuracy: 0.8607 - loss: 0.4831 - val_accuracy: 0.9582 - val_loss: 0.1478
# Epoch 2/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 11s 15ms/step - accuracy: 0.9601 - loss: 0.1344 - val_accuracy: 0.9670 - val_loss: 0.1107
# Epoch 3/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 4s 10ms/step - accuracy: 0.9762 - loss: 0.0817 - val_accuracy: 0.9735 - val_loss: 0.0906
# Epoch 4/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 5s 12ms/step - accuracy: 0.9835 - loss: 0.0551 - val_accuracy: 0.9749 - val_loss: 0.0846
# Epoch 5/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - accuracy: 0.9888 - loss: 0.0416 - val_accuracy: 0.9742 - val_loss: 0.0831
# Epoch 6/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 5s 10ms/step - accuracy: 0.9911 - loss: 0.0308 - val_accuracy: 0.9765 - val_loss: 0.0855
# Epoch 7/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 6s 13ms/step - accuracy: 0.9932 - loss: 0.0241 - val_accuracy: 0.9770 - val_loss: 0.0786
# Epoch 8/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 4s 10ms/step - accuracy: 0.9953 - loss: 0.0174 - val_accuracy: 0.9785 - val_loss: 0.0768
# Epoch 9/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - accuracy: 0.9971 - loss: 0.0123 - val_accuracy: 0.9785 - val_loss: 0.0747
# Epoch 10/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 5s 13ms/step - accuracy: 0.9981 - loss: 0.0093 - val_accuracy: 0.9788 - val_loss: 0.0861

# %% [markdown]
# **Using the model to make predictions**

# %%
test_digits = test_images[0:10]
predictions = model.predict(test_digits)
predictions[0]
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# array([9.1390791e-11, 7.1731544e-11, 1.1532972e-07, 1.0050784e-06,
#        1.1021734e-17, 4.1820609e-11, 2.7055926e-17, 9.9999887e-01,
#        3.0962607e-10, 4.0191463e-09], dtype=float32)

# %%
predictions[0].argmax()
# Out:
# np.int64(7)

# %%
predictions[0][7]
# Out:
# np.float32(0.99999887)

# %%
test_labels[0]
# Out:
# np.uint8(7)

# %% [markdown]
# **Evaluating the model on new data**

# %%
test_loss, test_acc = model.evaluate(test_images, test_labels)
print(f"test_acc: {test_acc}")
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9754 - loss: 0.0864
# test_acc: 0.9787999987602234

# %% [markdown]
# ## Data representations for neural networks

# %% [markdown]
# ### Scalars (rank-0 tensors)

# %%
import numpy as np
x = np.array(12)
x
# Out:
# array(12)

# %%
x.ndim
# Out:
# 0

# %% [markdown]
# ### Vectors (rank-1 tensors)

# %%
x = np.array([12, 3, 6, 14, 7])
x
# Out:
# array([12,  3,  6, 14,  7])

# %%
x.ndim
# Out:
# 1

# %% [markdown]
# ### Matrices (rank-2 tensors)

# %%
x = np.array([[5, 78, 2, 34, 0],
              [6, 79, 3, 35, 1],
              [7, 80, 4, 36, 2]])
x.ndim
# Out:
# 2

# %% [markdown]
# ### Rank-3 and higher-rank tensors

# %%
x = np.array([[[5, 78, 2, 34, 0],
               [6, 79, 3, 35, 1],
               [7, 80, 4, 36, 2]],
              [[5, 78, 2, 34, 0],
               [6, 79, 3, 35, 1],
               [7, 80, 4, 36, 2]],
              [[5, 78, 2, 34, 0],
               [6, 79, 3, 35, 1],
               [7, 80, 4, 36, 2]]])
x.ndim
# Out:
# 3

# %% [markdown]
# ### Key attributes

# %%
from tensorflow.keras.datasets import mnist
(train_images, train_labels), (test_images, test_labels) = mnist.load_data()

# %%
train_images.ndim
# Out:
# 3

# %%
train_images.shape
# Out:
# (60000, 28, 28)

# %%
train_images.dtype
# Out:
# dtype('uint8')

# %% [markdown]
# **Displaying the fourth digit**

# %%
import matplotlib.pyplot as plt
digit = train_images[4]
plt.imshow(digit, cmap=plt.cm.binary)
plt.show()

# %%
train_labels[4]
# Out:
# np.uint8(9)

# %% [markdown]
# ### Manipulating tensors in NumPy

# %%
my_slice = train_images[10:100]
my_slice.shape
# Out:
# (90, 28, 28)

# %%
my_slice = train_images[10:100, :, :]
my_slice.shape
# Out:
# (90, 28, 28)

# %%
my_slice = train_images[10:100, 0:28, 0:28]
my_slice.shape
# Out:
# (90, 28, 28)

# %%
my_slice = train_images[:, 14:, 14:]

# %%
my_slice = train_images[:, 7:-7, 7:-7]

# %% [markdown]
# ### The notion of data batches

# %%
batch = train_images[:128]

# %%
batch = train_images[128:256]

# %%
n = 3
batch = train_images[128 * n:128 * (n + 1)]

# %% [markdown]
# ### Real-world examples of data tensors

# %% [markdown]
# ### Vector data

# %% [markdown]
# ### Timeseries data or sequence data

# %% [markdown]
# ### Image data

# %% [markdown]
# ### Video data

# %% [markdown]
# ## The gears of neural networks: tensor operations

# %% [markdown]
# ### Element-wise operations

# %%
def naive_relu(x):
    assert len(x.shape) == 2
    x = x.copy()
    for i in range(x.shape[0]):
        for j in range(x.shape[1]):
            x[i, j] = max(x[i, j], 0)
    return x

# %%
def naive_add(x, y):
    assert len(x.shape) == 2
    assert x.shape == y.shape
    x = x.copy()
    for i in range(x.shape[0]):
        for j in range(x.shape[1]):
            x[i, j] += y[i, j]
    return x

# %%
import time

x = np.random.random((20, 100))
y = np.random.random((20, 100))

t0 = time.time()
for _ in range(1000):
    z = x + y
    z = np.maximum(z, 0.)
print("Took: {0:.2f} s".format(time.time() - t0))
# Out:
# Took: 0.01 s

# %%
t0 = time.time()
for _ in range(1000):
    z = naive_add(x, y)
    z = naive_relu(z)
print("Took: {0:.2f} s".format(time.time() - t0))
# Out:
# Took: 1.90 s

# %% [markdown]
# ### Broadcasting

# %%
import numpy as np
X = np.random.random((32, 10))
y = np.random.random((10,))

# %%
y = np.expand_dims(y, axis=0)

# %%
Y = np.concatenate([y] * 32, axis=0)

# %%
def naive_add_matrix_and_vector(x, y):
    assert len(x.shape) == 2
    assert len(y.shape) == 1
    assert x.shape[1] == y.shape[0]
    x = x.copy()
    for i in range(x.shape[0]):
        for j in range(x.shape[1]):
            x[i, j] += y[j]
    return x

# %%
import numpy as np
x = np.random.random((64, 3, 32, 10))
y = np.random.random((32, 10))
z = np.maximum(x, y)

# %% [markdown]
# ### Tensor product

# %%
x = np.random.random((32,))
y = np.random.random((32,))
z = np.dot(x, y)

# %%
def naive_vector_dot(x, y):
    assert len(x.shape) == 1
    assert len(y.shape) == 1
    assert x.shape[0] == y.shape[0]
    z = 0.
    for i in range(x.shape[0]):
        z += x[i] * y[i]
    return z

# %%
def naive_matrix_vector_dot(x, y):
    assert len(x.shape) == 2
    assert len(y.shape) == 1
    assert x.shape[1] == y.shape[0]
    z = np.zeros(x.shape[0])
    for i in range(x.shape[0]):
        for j in range(x.shape[1]):
            z[i] += x[i, j] * y[j]
    return z

# %%
def naive_matrix_vector_dot(x, y):
    z = np.zeros(x.shape[0])
    for i in range(x.shape[0]):
        z[i] = naive_vector_dot(x[i, :], y)
    return z

# %%
def naive_matrix_dot(x, y):
    assert len(x.shape) == 2
    assert len(y.shape) == 2
    assert x.shape[1] == y.shape[0]
    z = np.zeros((x.shape[0], y.shape[1]))
    for i in range(x.shape[0]):
        for j in range(y.shape[1]):
            row_x = x[i, :]
            column_y = y[:, j]
            z[i, j] = naive_vector_dot(row_x, column_y)
    return z

# %% [markdown]
# ### Tensor reshaping

# %%
train_images = train_images.reshape((60000, 28 * 28))

# %%
x = np.array([[0., 1.],
             [2., 3.],
             [4., 5.]])
x.shape
# Out:
# (3, 2)

# %%
x = x.reshape((6, 1))
x
# Out:
# array([[0.],
#        [1.],
#        [2.],
#        [3.],
#        [4.],
#        [5.]])

# %%
x = np.zeros((300, 20))
x = np.transpose(x)
x.shape
# Out:
# (20, 300)

# %% [markdown]
# ### Geometric interpretation of tensor operations

# %% [markdown]
# ### A geometric interpretation of deep learning

# %% [markdown]
# ## The engine of neural networks: gradient-based optimization

# %% [markdown]
# ### What's a derivative?

# %% [markdown]
# ### Derivative of a tensor operation: the gradient

# %% [markdown]
# ### Stochastic gradient descent

# %% [markdown]
# ### Chaining derivatives: The Backpropagation algorithm

# %% [markdown]
# #### The chain rule

# %% [markdown]
# #### Automatic differentiation with computation graphs

# %% [markdown]
# #### The gradient tape in TensorFlow

# %%
import tensorflow as tf
x = tf.Variable(0.)
with tf.GradientTape() as tape:
    y = 2 * x + 3
grad_of_y_wrt_x = tape.gradient(y, x)

# %%
x = tf.Variable(tf.random.uniform((2, 2)))
with tf.GradientTape() as tape:
    y = 2 * x + 3
grad_of_y_wrt_x = tape.gradient(y, x)

# %%
W = tf.Variable(tf.random.uniform((2, 2)))
b = tf.Variable(tf.zeros((2,)))
x = tf.random.uniform((2, 2))
with tf.GradientTape() as tape:
    y = tf.matmul(x, W) + b
grad_of_y_wrt_W_and_b = tape.gradient(y, [W, b])

# %% [markdown]
# ## Looking back at our first example

# %%
(train_images, train_labels), (test_images, test_labels) = mnist.load_data()
train_images = train_images.reshape((60000, 28 * 28))
train_images = train_images.astype("float32") / 255
test_images = test_images.reshape((10000, 28 * 28))
test_images = test_images.astype("float32") / 255

# %%
model = keras.Sequential([
    layers.Dense(512, activation="relu"),
    layers.Dense(10, activation="softmax")
])

# %%
model.compile(optimizer="rmsprop",
              loss="sparse_categorical_crossentropy",
              metrics=["accuracy"])

# %%
model.fit(train_images, train_labels, epochs=5, batch_size=128)
# Out:
# Epoch 1/5
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 6s 11ms/step - accuracy: 0.8707 - loss: 0.4388
# Epoch 2/5
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step - accuracy: 0.9670 - loss: 0.1124
# Epoch 3/5
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step - accuracy: 0.9781 - loss: 0.0717
# Epoch 4/5
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 5s 11ms/step - accuracy: 0.9846 - loss: 0.0518
# Epoch 5/5
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 9s 9ms/step - accuracy: 0.9888 - loss: 0.0366

# %% [markdown]
# ### Reimplementing our first example from scratch in TensorFlow

# %% [markdown]
# #### A simple Dense class

# %%
import tensorflow as tf

class NaiveDense:
    def __init__(self, input_size, output_size, activation):
        self.activation = activation

        w_shape = (input_size, output_size)
        w_initial_value = tf.random.uniform(w_shape, minval=0, maxval=1e-1)
        self.W = tf.Variable(w_initial_value)

        b_shape = (output_size,)
        b_initial_value = tf.zeros(b_shape)
        self.b = tf.Variable(b_initial_value)

    def __call__(self, inputs):
        return self.activation(tf.matmul(inputs, self.W) + self.b)

    @property
    def weights(self):
        return [self.W, self.b]

# %% [markdown]
# #### A simple Sequential class

# %%
class NaiveSequential:
    def __init__(self, layers):
        self.layers = layers

    def __call__(self, inputs):
        x = inputs
        for layer in self.layers:
           x = layer(x)
        return x

    @property
    def weights(self):
       weights = []
       for layer in self.layers:
           weights += layer.weights
       return weights

# %%
model = NaiveSequential([
    NaiveDense(input_size=28 * 28, output_size=512, activation=tf.nn.relu),
    NaiveDense(input_size=512, output_size=10, activation=tf.nn.softmax)
])
assert len(model.weights) == 4

# %% [markdown]
# #### A batch generator

# %%
import math

class BatchGenerator:
    def __init__(self, images, labels, batch_size=128):
        assert len(images) == len(labels)
        self.index = 0
        self.images = images
        self.labels = labels
        self.batch_size = batch_size
        self.num_batches = math.ceil(len(images) / batch_size)

    def next(self):
        images = self.images[self.index : self.index + self.batch_size]
        labels = self.labels[self.index : self.index + self.batch_size]
        self.index += self.batch_size
        return images, labels

# %% [markdown]
# ### Running one training step

# %%
def one_training_step(model, images_batch, labels_batch):
    with tf.GradientTape() as tape:
        predictions = model(images_batch)
        per_sample_losses = tf.keras.losses.sparse_categorical_crossentropy(
            labels_batch, predictions)
        average_loss = tf.reduce_mean(per_sample_losses)
    gradients = tape.gradient(average_loss, model.weights)
    update_weights(gradients, model.weights)
    return average_loss

# %%
learning_rate = 1e-3

def update_weights(gradients, weights):
    for g, w in zip(gradients, weights):
        w.assign_sub(g * learning_rate)

# %%
from tensorflow.keras import optimizers

optimizer = optimizers.SGD(learning_rate=1e-3)

def update_weights(gradients, weights):
    optimizer.apply_gradients(zip(gradients, weights))

# %% [markdown]
# ### The full training loop

# %%
def fit(model, images, labels, epochs, batch_size=128):
    for epoch_counter in range(epochs):
        print(f"Epoch {epoch_counter}")
        batch_generator = BatchGenerator(images, labels)
        for batch_counter in range(batch_generator.num_batches):
            images_batch, labels_batch = batch_generator.next()
            loss = one_training_step(model, images_batch, labels_batch)
            if batch_counter % 100 == 0:
                print(f"loss at batch {batch_counter}: {loss:.2f}")

# %%
from tensorflow.keras.datasets import mnist
(train_images, train_labels), (test_images, test_labels) = mnist.load_data()

train_images = train_images.reshape((60000, 28 * 28))
train_images = train_images.astype("float32") / 255
test_images = test_images.reshape((10000, 28 * 28))
test_images = test_images.astype("float32") / 255

fit(model, train_images, train_labels, epochs=10, batch_size=128)
# Out:
# Epoch 0
# loss at batch 0: 3.60
# loss at batch 100: 2.26
# loss at batch 200: 2.23
# loss at batch 300: 2.10
# loss at batch 400: 2.24
# Epoch 1
# loss at batch 0: 1.93
# loss at batch 100: 1.89
# loss at batch 200: 1.85
# loss at batch 300: 1.72
# loss at batch 400: 1.85
# Epoch 2
# loss at batch 0: 1.60
# loss at batch 100: 1.59
# loss at batch 200: 1.52
# loss at batch 300: 1.42
# loss at batch 400: 1.53
# Epoch 3
# loss at batch 0: 1.34
# loss at batch 100: 1.35
# loss at batch 200: 1.25
# loss at batch 300: 1.21
# loss at batch 400: 1.29
# Epoch 4
# loss at batch 0: 1.14
# loss at batch 100: 1.16
# loss at batch 200: 1.05
# loss at batch 300: 1.04
# loss at batch 400: 1.12
# Epoch 5
# loss at batch 0: 0.99
# loss at batch 100: 1.02
# loss at batch 200: 0.91
# loss at batch 300: 0.92
# loss at batch 400: 1.00
# Epoch 6
# loss at batch 0: 0.88
# loss at batch 100: 0.91
# loss at batch 200: 0.80
# loss at batch 300: 0.83
# loss at batch 400: 0.91
# Epoch 7
# loss at batch 0: 0.80
# loss at batch 100: 0.83
# loss at batch 200: 0.72
# loss at batch 300: 0.76
# loss at batch 400: 0.84
# Epoch 8
# loss at batch 0: 0.73
# loss at batch 100: 0.76
# loss at batch 200: 0.66
# loss at batch 300: 0.71
# loss at batch 400: 0.79
# Epoch 9
# loss at batch 0: 0.68
# loss at batch 100: 0.70
# loss at batch 200: 0.61
# loss at batch 300: 0.66
# loss at batch 400: 0.75

# %% [markdown]
# ### Evaluating the model

# %%
predictions = model(test_images)
predictions = predictions.numpy()
predicted_labels = np.argmax(predictions, axis=1)
matches = predicted_labels == test_labels
print(f"accuracy: {matches.mean():.2f}")
# Out:
# accuracy: 0.82

# %% [markdown]
# ## Summary

# %%
import matplotlib.pyplot as plt

if 'history' in locals() or 'history' in globals():
    history_dict = history.history
    loss_values = history_dict["loss"]
    acc_values = history_dict["accuracy"]
    epochs = range(1, len(loss_values) + 1)

    plt.figure(figsize=(12, 5))

    plt.subplot(1, 2, 1)
    plt.plot(epochs, loss_values, "bo", label="Training loss")
    plt.title("Training loss")
    plt.xlabel("Epochs")
    plt.ylabel("Loss")
    plt.legend()

    plt.subplot(1, 2, 2)
    plt.plot(epochs, acc_values, "ro", label="Training acc")
    plt.title("Training accuracy")
    plt.xlabel("Epochs")
    plt.ylabel("Accuracy")
    plt.legend()

    plt.show()

# %% [markdown]
# ### Removing 2 pixel padding

# %%
import numpy as np

(train_images_orig, train_labels), (test_images_orig, test_labels) = mnist.load_data()

train_images_cropped = train_images_orig[:, 2:-2, 2:-2]
test_images_cropped = test_images_orig[:, 2:-2, 2:-2]

train_images_cropped = train_images_cropped.reshape((60000, 24 * 24)).astype("float32") / 255
test_images_cropped = test_images_cropped.reshape((10000, 24 * 24)).astype("float32") / 255

model_cropped = keras.Sequential([
    layers.Dense(512, activation="relu"),
    layers.Dense(10, activation="softmax")
])

model_cropped.compile(optimizer="rmsprop",
                      loss="sparse_categorical_crossentropy",
                      metrics=["accuracy"])

model_cropped.fit(train_images_cropped, train_labels, epochs=5, batch_size=128, verbose=1)

test_loss_crop, test_acc_crop = model_cropped.evaluate(test_images_cropped, test_labels)
print(f"Test accuracy (cropped 24x24): {test_acc_crop:.4f}")
# Out:
# Epoch 1/5
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 4s 7ms/step - accuracy: 0.8672 - loss: 0.4501
# Epoch 2/5
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - accuracy: 0.9667 - loss: 0.1167
# Epoch 3/5
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 5s 8ms/step - accuracy: 0.9779 - loss: 0.0746
# Epoch 4/5
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - accuracy: 0.9849 - loss: 0.0493
# Epoch 5/5
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - accuracy: 0.9887 - loss: 0.0403
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9763 - loss: 0.0811
# Test accuracy (cropped 24x24): 0.9801

# %% [markdown]
# ### Permutation

# %%
(train_images, train_labels), (test_images, test_labels) = mnist.load_data()

train_images = train_images.reshape((60000, 28 * 28)).astype("float32") / 255
test_images = test_images.reshape((10000, 28 * 28)).astype("float32") / 255

permutation = np.random.permutation(28 * 28)

train_images_permuted = train_images[:, permutation]
test_images_permuted = test_images[:, permutation]

model_permuted = keras.Sequential([
    layers.Dense(512, activation="relu"),
    layers.Dense(10, activation="softmax")
])

model_permuted.compile(optimizer="rmsprop",
                       loss="sparse_categorical_crossentropy",
                       metrics=["accuracy"])

model_permuted.fit(train_images_permuted, train_labels, epochs=5, batch_size=128, verbose=1)

test_loss_perm, test_acc_perm = model_permuted.evaluate(test_images_permuted, test_labels)
print(f"Test accuracy (permuted): {test_acc_perm:.4f}")
# Out:
# Epoch 1/5
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 5s 9ms/step - accuracy: 0.8713 - loss: 0.4391
# Epoch 2/5
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 6s 11ms/step - accuracy: 0.9657 - loss: 0.1153
# Epoch 3/5
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step - accuracy: 0.9789 - loss: 0.0707
# Epoch 4/5
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step - accuracy: 0.9845 - loss: 0.0524
# Epoch 5/5
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 5s 11ms/step - accuracy: 0.9885 - loss: 0.0401
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9721 - loss: 0.0849
# Test accuracy (permuted): 0.9773
